# %%
# quick exercise 3

# %%
ls
# Out:
# 01_intro.ipynb                       04_shell_and_magic.ipynb
# 01_intro_to_notebook.ipynb           dropbox_2020.03.04_amd64.deb
# 01-linear_algebra_numpy.empty.ipynb  Untitled.ipynb
# 02_flow_control.ipynb                untitled.txt
# 03_functions_and_strings.ipynb

# %%
cd Home/Data

ls
# Out:
#   File "<ipython-input-23-eb6d4edca2df>", line 1
#     cd Home/Data
#           ^
# SyntaxError: invalid syntax

# %%
# %cd ..
# Out:
# /home

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: /home/dsc/Downloads

# %%
for name in _dh:
    print(name)
    ! ls -l  $name| wc -l
# Out:
# /home/dsc/Downloads
# 10

# %%
def count(file, pattern):
    
    f = open(file)
    
    f = f.readlines()
    
    count = 0
    
    for line in lines:
        if line.find(pattern) != -1:
            count+=1
            
    return count

path = '/home/Data/Finn.txt'

count(path, 'Hucleberry')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-591addd74cfa> in <module>
#      15 path = '/home/Data/Finn.txt'
#      16
# ---> 17 count(path, 'Hucleberry')
#
# <ipython-input-27-591addd74cfa> in count(file, pattern)
#       1 def count(file, pattern):
#       2
# ----> 3     f = open(file)
#       4
#       5     f = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/Data/Finn.txt'

# %%
def count(file, pattern):
    
   with open(file) as f:
    lines = f.readlines()
    count = 0
    
    
    for line in lines:
        if line.find(pattern) != -1:
            count+=1
            
    print(f.closed)
    
    return count
            
path = '/Home/Data/Finn.txt'

count(path, 'Hucleberry')

# %%
def count(file, pattern):
    
    
    with open(file) as f:
        
          lines = f.readlines()
        count = 0
          
    
    
    for line in lines:
        if pattern in line:
            count+=1
            
        print(f.closed) #nunca cerrado
    print(f.closed) #garantixocerrado
    
    
    
    return count
            
path = '/Home/Data/Finn.txt'

count(path, 'Hucleberry')
# Out:
#   File "<ipython-input-18-d36182271d6f>", line 7
#     count = 0
#     ^
# IndentationError: unexpected indent

# %%
f = open(path)
lines = f.readlines()
result = []

for line in lines:
    result.append(lines.rstrip())
    
    
target = open('NewFinn.txt', 'w') 
target.writelines(result)
target.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-f1baabbca907> in <module>
# ----> 1 f = open(path)
#       2 lines = f.readlines()
#       3 result = []
#       4
#       5 for line in lines:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Home/Data/Finn.txt'

# %%
f = open(path)
lines = f.readlines()
result = []

target = open('NewFinn.txt', 'w')
for line in lines:
    target.write (lines.rstrip() + '\n')
    
    
 
target.writelines(result)
target.close()
# !wc -l NewFinn.txt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-be3030e0b4e7> in <module>
# ----> 1 f = open(path)
#       2 lines = f.readlines()
#       3 result = []
#       4
#       5 target = open('NewFinn.txt', 'w')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Home/Data/Finn.txt'

# %%
# Data structures

# %%
LIST

# %%
EMPTY =[]
help(EMPTY)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
empty = []

# %%
x = empty.append('element')

# %%
print(x) # función impura
# Out:
# None

# %%
empty # 2 elementos xq he ejecutado dos veces
# Out:
# ['element', 'element']

# %%
list('kjdjclkzj') # crear lista
# Out:
# ['k', 'j', 'd', 'j', 'c', 'l', 'k', 'z', 'j']

# %%
a_list=list('jhskjdfhkjs')
a_list
# Out:
# ['j', 'h', 's', 'k', 'j', 'd', 'f', 'h', 'k', 'j', 's']

# %%
sorted(a_list) # copia ordenada
# Out:
# ['d', 'f', 'h', 'h', 'j', 'j', 'j', 'k', 'k', 's', 's']

# %%
sorted_copy= sorted(a_list)
 # no se modifica la original
# Out:
# ['d', 'f', 'h', 'h', 'j', 'j', 'j', 'k', 'k', 's', 's']

# %%
a_list.sort()

# %%
a_list
# Out:
# ['d', 'f', 'h', 'h', 'j', 'j', 'j', 'k', 'k', 's', 's']

# %%
a_string = 'hola colegui'
a_string.upper() # esto es un método str xa solo tiene sentido para str no list
# Out:
# 'HOLA COLEGUI'

# %%
a_list.insert(0,'x') # ver ayuda pone que primero index

# %%
a_list
# Out:
# ['x', 'd', 'f', 'h', 'h', 'j', 'j', 'j', 'k', 'k', 's', 's']

# %%
a_list.insert(5,'chachi')
a_list
# Out:
# ['x',
#  'd',
#  'f',
#  'h',
#  'h',
#  'chachi',
#  'chachi',
#  'j',
#  'j',
#  'j',
#  'k',
#  'k',
#  's',
#  's']

# %%
#unir 2 listas

another_list = ['uan','pelotilla']

# %%
concatenated= another_list + a_list # concatenación

# %%
another_list.append(a_list) 
concatenated == another_list #mete una lista con otra lista,x eso false
# Out:
# False

# %%
another_list
# Out:
# ['uan',
#  'pelotilla',
#  ['x',
#   'd',
#   'f',
#   'h',
#   'h',
#   'chachi',
#   'chachi',
#   'j',
#   'j',
#   'j',
#   'k',
#   'k',
#   's',
#   's']]

# %%
third_list = ['que', 'de', 'listas']
third_list.extend(a_list) # no es igual que mas, este modifica in place

# %%
third_list
# Out:
# ['que',
#  'de',
#  'listas',
#  'x',
#  'd',
#  'f',
#  'h',
#  'h',
#  'chachi',
#  'chachi',
#  'j',
#  'j',
#  'j',
#  'k',
#  'k',
#  's',
#  's']

# %%
result = []
for line in lines:
    if line != '\n'
    result.append(line)
result

# %%
# %%timeit #las magic son de jupyter

result_b=[]
for line in lines:
    if line != '\n'
    result_b= result + [line] #line en corchetes porque son listas y line es str

result_b == result

#el resultado el tiempo es muy diferente_dibujocuaderno y da true

# %%
#con el operador incremento += si que puedo

a= []
a += ['x']
a
# Out:
# ['x']

# %%
a_list.remove('chachi')

# %%
a_list
# Out:
# ['x', 'd', 'f', 'h', 'h', 'chachi', 'j', 'j', 'j', 'k', 'k', 's', 's']

# %%
a_list.pop(4)#me elimina la de la posición 4
# Out:
# 'h'

# %%
a_list
# Out:
# ['x', 'd', 'f', 'h', 'chachi', 'j', 'j', 'j', 'k', 'k', 's', 's']

# %%
a_list.index('d') # si no hubier d ,e saldría un error
# Out:
# 1

# %%
FUNCIONES ANONIMAS_LAMBDA FUNCTIONS

# %%
# EN PYTHON TODO ES UN OBJETO,puedo manipularlo

# %%
def last_word(sentence):
    return sentence.split()[-1] #pasar a lista para indexae

cuentito = 'Erase una vez'
last_word(cuentito)
# Out:
# 'vez'

# %%
type(last_word)
# Out:
# function

# %%
path = '/home/dsc/Data/shell/Finn.txt'
with open (path) as f:
    lines = f.readlines()
    
len(lines)
# Out:
# 12363

# %%
def process_a(lines):
    result = []
    
    for line in lines:
        if len(line) >1:
            result.append(last_word(line))
    return result

process_a(lines)
# Out:
# ['\ufeff',
#  'Complete',
#  'Clemens)',
#  'almost',
#  're-use',
#  'this',
#  'www.gutenberg.net',
#  'Complete',
#  'Clemens)',
#  '#76]',
#  '2016]',
#  'English',
#  'UTF-8',
#  '***',
#  'Widger',
#  'ADVENTURES',
#  'OF',
#  'FINN',
#  'Comrade)',
#  'Twain',
#  'Complete',
#  'CONTENTS.',
#  'Waits.',
#  'Plans.',
#  'Sawyers’s',
#  'Lies”.',
#  'Judge.--Superstition.',
#  'Parent.--Reform.',
#  'Leave.--Political',
#  'Around.',
#  'the',
#  'Body.--Resting.',
#  'the',
#  'Escape.--Signs.--Balum.',
#  'House.',
#  'Disguise.',
#  'to',
#  'Goshen.',
#  'Wreck.--The',
#  'Boat.',
#  'Watchman.--Sinking.',
#  'Harem.--French.',
#  'Raft.--Trash.',
#  'by',
#  'Ashore.',
#  'Arkansaw.--Interior',
#  'Effusions.',
#  'Grangerford.--Aristocracy.--Feuds.--The',
#  'Cabbage.',
#  'a',
#  'Royalty.',
#  'the',
#  'Printer.',
#  'Around',
#  'Boggs.--Dead.',
#  'the',
#  'Tragedy.',
#  'Home-sick.',
#  'Passenger.--Getting',
#  'Grief.',
#  'Square--Funeral',
#  '.',
#  'His',
# ...

# %%
def process_b(lines):
    result = []
    
    for line in lines:
        if len(line) >1:
            result.append(line[0]) # saca primera letra de cada linea
    return result

process_b(lines)
# Out:
# ['\ufeff',
#  'T',
#  'b',
#  'T',
#  'n',
#  'i',
#  'e',
#  'T',
#  'A',
#  'R',
#  'L',
#  'L',
#  'C',
#  '*',
#  'P',
#  'A',
#  'O',
#  'H',
#  '(',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'L',
#  'C',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'I',
#  'C',
#  'C',
#  'C',
#  'G',
#  'C',
#  'P',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'C',
#  'T',
#  'C',
#  'T',
#  'C',
#  'C',
#  'C',
#  'T',
#  'C',
#  'R',
#  'C',
#  'C',
#  'I',
#  'C',
#  'O',
#  'C',
#  'P',
#  'C',
#  'H',
#  'C',
#  'L',
#  'C',
#  'Q',
#  'C',
#  'C',
#  'S',
#  'C',
#  'a',
#  'C',
#  'B',
#  'C',
#  'L',
#  'C',
#  'S',
#  'C',
#  'P',
#  'C',
#  'W',
#  'C',
#  'G',
#  'C',
#  'C',
#  'a',
#  'C',
#  'T',
#  'C',
#  'C',
#  'C',
#  'F',
#  'I',
#  'T',
#  'M',
#  'M',
#  'H',
#  'T',
#  'J',
#  'T',
#  'H',
#  'M',
#  'T',
#  'R',
#  '!',
#  'J',
#  'J',
#  '“',
#  'H',
#  'R',
#  'F',
#  'T',
#  'M',
#  'M',
#  'H',
#  'T',
#  'J',
#  'T',
#  'H',
#  'M',
# ...

# %%
#poco flexibled xq solo hacen una cosa, pero vale xa cualquier lista
#hacer un argumento a la función xa hacerla  con f, que es lo que queramos

# %%
def process(f, lines):
    result = []
    
    for line in lines:
        if len(line) >1:
            result.append(f(line))
    return result

process(len,lines) #(str.upper, lines) (word, lines)...etc
# Out:
# [2,
#  72,
#  31,
#  72,
#  68,
#  71,
#  37,
#  48,
#  36,
#  42,
#  31,
#  18,
#  30,
#  63,
#  25,
#  11,
#  3,
#  17,
#  23,
#  14,
#  9,
#  10,
#  61,
#  72,
#  74,
#  7,
#  47,
#  53,
#  75,
#  28,
#  64,
#  16,
#  71,
#  53,
#  43,
#  53,
#  71,
#  8,
#  75,
#  33,
#  64,
#  55,
#  76,
#  72,
#  25,
#  64,
#  57,
#  60,
#  69,
#  70,
#  72,
#  64,
#  71,
#  70,
#  39,
#  68,
#  30,
#  62,
#  67,
#  28,
#  74,
#  28,
#  63,
#  52,
#  66,
#  30,
#  73,
#  67,
#  70,
#  64,
#  68,
#  74,
#  30,
#  76,
#  11,
#  72,
#  29,
#  69,
#  39,
#  67,
#  24,
#  65,
#  27,
#  71,
#  11,
#  74,
#  27,
#  61,
#  75,
#  10,
#  73,
#  9,
#  60,
#  60,
#  74,
#  6,
#  15,
#  11,
#  27,
#  12,
#  19,
#  20,
#  4,
#  31,
#  28,
#  22,
#  22,
#  17,
#  8,
#  25,
#  14,
#  6,
#  20,
#  23,
#  19,
#  11,
#  27,
#  12,
#  19,
#  20,
#  4,
#  31,
#  28,
#  22,
#  22,
#  17,
#  8,
#  25,
#  14,
#  6,
#  20,
#  23,
#  19,
#  23,
#  14,
#  17,
#  15,
#  9,
#  11,
#  17,
#  14,
#  13,
#  18,
#  26,
# ...

# %%
list(map(len,lines))
# Out:
# [2,
#  1,
#  72,
#  31,
#  1,
#  72,
#  68,
#  71,
#  37,
#  1,
#  48,
#  1,
#  36,
#  1,
#  42,
#  1,
#  31,
#  1,
#  18,
#  1,
#  30,
#  1,
#  63,
#  1,
#  25,
#  1,
#  1,
#  1,
#  1,
#  1,
#  11,
#  1,
#  3,
#  1,
#  17,
#  1,
#  23,
#  1,
#  14,
#  1,
#  9,
#  1,
#  1,
#  1,
#  1,
#  10,
#  1,
#  61,
#  1,
#  72,
#  1,
#  74,
#  7,
#  1,
#  47,
#  1,
#  53,
#  1,
#  75,
#  28,
#  1,
#  64,
#  16,
#  1,
#  71,
#  53,
#  1,
#  43,
#  1,
#  53,
#  1,
#  71,
#  8,
#  1,
#  75,
#  33,
#  1,
#  64,
#  1,
#  55,
#  1,
#  76,
#  1,
#  72,
#  25,
#  1,
#  64,
#  57,
#  1,
#  60,
#  69,
#  1,
#  70,
#  72,
#  1,
#  64,
#  71,
#  1,
#  70,
#  39,
#  1,
#  68,
#  30,
#  1,
#  62,
#  1,
#  67,
#  28,
#  1,
#  74,
#  28,
#  1,
#  63,
#  52,
#  1,
#  66,
#  30,
#  1,
#  73,
#  67,
#  1,
#  70,
#  64,
#  1,
#  68,
#  1,
#  74,
#  30,
#  1,
#  76,
#  11,
#  1,
#  72,
#  29,
#  1,
#  69,
#  39,
#  1,
#  67,
#  24,
#  1,
#  65,
#  27,
#  1,
#  71,
#  11,
#  1,
#  74,
#  27,
#  1,
#  61,
#  1,
# ...

# %%
lambda argument: argument[0] #escribir en una linea un funcio, paso cualquier argumetno y me devuelve lo primero
#lambda es una funcion desnuda
#me permite meter como arg una función
# para cosas que no vaya a utilizar mucho 
#para dar criterios?
# Out:
# <function __main__.<lambda>(argument)>

# %%
g= lambda argument: argument[0]
type(g)
# Out:
# function

# %%
process(lambda line: line[0], lines) # el line cualquier cosa
# Out:
# ['\ufeff',
#  'T',
#  'b',
#  'T',
#  'n',
#  'i',
#  'e',
#  'T',
#  'A',
#  'R',
#  'L',
#  'L',
#  'C',
#  '*',
#  'P',
#  'A',
#  'O',
#  'H',
#  '(',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'L',
#  'C',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'I',
#  'C',
#  'C',
#  'C',
#  'G',
#  'C',
#  'P',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'C',
#  'T',
#  'C',
#  'T',
#  'C',
#  'C',
#  'C',
#  'T',
#  'C',
#  'R',
#  'C',
#  'C',
#  'I',
#  'C',
#  'O',
#  'C',
#  'P',
#  'C',
#  'H',
#  'C',
#  'L',
#  'C',
#  'Q',
#  'C',
#  'C',
#  'S',
#  'C',
#  'a',
#  'C',
#  'B',
#  'C',
#  'L',
#  'C',
#  'S',
#  'C',
#  'P',
#  'C',
#  'W',
#  'C',
#  'G',
#  'C',
#  'C',
#  'a',
#  'C',
#  'T',
#  'C',
#  'C',
#  'C',
#  'F',
#  'I',
#  'T',
#  'M',
#  'M',
#  'H',
#  'T',
#  'J',
#  'T',
#  'H',
#  'M',
#  'T',
#  'R',
#  '!',
#  'J',
#  'J',
#  '“',
#  'H',
#  'R',
#  'F',
#  'T',
#  'M',
#  'M',
#  'H',
#  'T',
#  'J',
#  'T',
#  'H',
#  'M',
# ...

# %%
def first_element(argument):
    return argument[0]

# %%
process(lambda x: x[0], lines)
# Out:
# ['\ufeff',
#  'T',
#  'b',
#  'T',
#  'n',
#  'i',
#  'e',
#  'T',
#  'A',
#  'R',
#  'L',
#  'L',
#  'C',
#  '*',
#  'P',
#  'A',
#  'O',
#  'H',
#  '(',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'L',
#  'C',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'I',
#  'C',
#  'C',
#  'C',
#  'G',
#  'C',
#  'P',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'C',
#  'T',
#  'C',
#  'T',
#  'C',
#  'C',
#  'C',
#  'T',
#  'C',
#  'R',
#  'C',
#  'C',
#  'I',
#  'C',
#  'O',
#  'C',
#  'P',
#  'C',
#  'H',
#  'C',
#  'L',
#  'C',
#  'Q',
#  'C',
#  'C',
#  'S',
#  'C',
#  'a',
#  'C',
#  'B',
#  'C',
#  'L',
#  'C',
#  'S',
#  'C',
#  'P',
#  'C',
#  'W',
#  'C',
#  'G',
#  'C',
#  'C',
#  'a',
#  'C',
#  'T',
#  'C',
#  'C',
#  'C',
#  'F',
#  'I',
#  'T',
#  'M',
#  'M',
#  'H',
#  'T',
#  'J',
#  'T',
#  'H',
#  'M',
#  'T',
#  'R',
#  '!',
#  'J',
#  'J',
#  '“',
#  'H',
#  'R',
#  'F',
#  'T',
#  'M',
#  'M',
#  'H',
#  'T',
#  'J',
#  'T',
#  'H',
#  'M',
# ...

# %%
firs_element = lambda arg: arg[0]

# %%
#lambda + nombre args: valor de retorno(donde metes las cosas). solo una linea

# %%
words = 'caperucita y el lobo feroz en realida lo planearon todo'.split()
words
# Out:
# ['caperucita',
#  'y',
#  'el',
#  'lobo',
#  'feroz',
#  'en',
#  'realida',
#  'lo',
#  'planearon',
#  'todo']

# %%
sorted(words) #ordenacion alfabetica
# Out:
# ['caperucita',
#  'el',
#  'en',
#  'feroz',
#  'lo',
#  'lobo',
#  'planearon',
#  'realida',
#  'todo',
#  'y']

# %%
sorted(words, key=len) # se le puede pasar una función con key=len es por longitud
# Out:
# ['y',
#  'el',
#  'en',
#  'lo',
#  'lobo',
#  'todo',
#  'feroz',
#  'realida',
#  'planearon',
#  'caperucita']

# %%
sorted(words, key = lambda word: word[-1])
# Out:
# ['caperucita',
#  'realida',
#  'el',
#  'en',
#  'planearon',
#  'lobo',
#  'lo',
#  'todo',
#  'y',
#  'feroz']

# %%
sorted(words, key= lambda word: word.count('a'))
# Out:
# ['y',
#  'el',
#  'lobo',
#  'feroz',
#  'en',
#  'lo',
#  'todo',
#  'caperucita',
#  'realida',
#  'planearon']

# %%
### Tuples

# %%
a_tuple = ('first', 2, 2.3, process)
type(a_tuple)
# Out:
# tuple

# %%
a_tuple.count('first') # solo de atributos count y index xq no implican modif
# Out:
# 1

# %%
a_tuple[0]
# Out:
# 'first'

# %%
a_tuple[2:]
# Out:
# (2.3, <function __main__.process(f, lines)>)

# %%
a_tuple[5:10] #me devuelve una tupla
# Out:
# ()

# %%
x = ()
type(x)
# Out:
# tuple

# %%
x =('casa')
type(x)
# Out:
# str

# %%
x =('casa',) #para que no sea str
type(x)
# Out:
# tuple

# %%
len(x)
# Out:
# 1

# %%
e=(1+3,)*7

print(e)
# Out:
# (4, 4, 4, 4, 4, 4, 4)

# %%
type(e)
# Out:
# tuple

# %%
a_tuple[0] = 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-20dd9aef0aa8> in <module>
# ----> 1 a_tuple[0] = 12
#
# TypeError: 'tuple' object does not support item assignment

# %%
another_tuple = (['pais', 'multicolor'], ['abeja', 'sol'])

# %%
another_tuple[1].append('!')

# %%
another_tuple
# Out:
# (['pais', 'multicolor'], ['abeja', 'sol', '!'])

# %%
another_tuple[0].pop()
# Out:
# 'multicolor'

# %%
another_tuple
# Out:
# (['pais'], ['abeja', 'sol', '!'])

# %%
###EXERCISE4

# %%
my_list = [1,2,3,4,5,6,7,8]
my_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list(map (lambda i : i**2, my_list))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
list(map (lambda i : i**2, range(1,9))) #mejor con range xq sino ocupa mogollon
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
my_str_list = ['casa', 'perro']

result = []

for i in my_str_list:
    for x in i:
        
        if x == 'a':
            result += x.upper()
        else:
            result += x.lower()

print(result) # su nivel depende de cuantas veces queramos repetir este bucle

#hay que hacer 2 listas para que te salga bien
# Out:
# ['c', 'A', 's', 'A', 'p', 'e', 'r', 'r', 'o']

# %%
word = 'casa'

final = ''

for i in word:
    if i == 'a':
        final+= i.upper()
        
    else:
        final += i.lower()
        

print(final)
# Out:
# cAsA

# %%
my_list = ['casa', 'perro']
character = 'a'
counter = ''

def names(my_list, character):
    counter = 0
    for i in my_list:
        for x in i:
            if x == character:
                counter+= 1
            else:
                continue
            
    print(counter)
                
names(['casa', 'perro'], 'a')
# Out:
# 2

# %%
def names(my_list, character):
    counter = 0
    for i in my_list:
      
        if  character in i:
            
            counter+= 1
        else:
            continue
       

            
    print(counter)
                
names(['casa', 'perro'], 'a')
# Out:
# 1

# %%
def names(my_list, character):
    counter = []
    for i in my_list:
        if  character in i:
            counter.append(i)     
        else:
            continue
       

            
    print(counter)
                
names(['casa', 'perro'], 'a')
# Out:
# ['casa']

# %%
my_string = 'casa'
my_string[::-1]
# Out:
# 'asac'

# %%
# enumerate() y zip()

# %%
list(enumerate(my_str_list)) # me enumera la lista
# Out:
# [(0, 'casa'), (1, 'perro')]

# %%
for index, my_str_list in enumerate(my_str_list):
    if index < 3:
        print(my_str_list)
# Out:
# o

# %%
for index, my_str_list in enumerate(my_str_list):
    if index %2 ==0:
        print (my_str_list)
# Out:
# o

# %%
adress = ['tribulete', 22, 3, 'b'] #para entender xq me sale p r o
street,number, floor, door = adress
number
# Out:
# 22

# %%
for index in range(len(my_str_list)):
    if index %2 ==0:
        print(my_str_list[index])
# Out:
# o

# %%
list(zip('abcde', 'jklmn'))
# Out:
# [('a', 'j'), ('b', 'k'), ('c', 'l'), ('d', 'm'), ('e', 'n')]

# %%
list(zip('qwerty', 'aeiou'))
# Out:
# [('q', 'a'), ('w', 'e'), ('e', 'i'), ('r', 'o'), ('t', 'u')]

# %%
list(zip('qwerty', 'aeiou', 'uuuuu'))
# Out:
# [('q', 'a', 'u'),
#  ('w', 'e', 'u'),
#  ('e', 'i', 'u'),
#  ('r', 'o', 'u'),
#  ('t', 'u', 'u')]

# %%
list(zip('qwerty', 'aeiou', 'uuuuu', 'www'))
# Out:
# [('q', 'a', 'u', 'w'), ('w', 'e', 'u', 'w'), ('e', 'i', 'u', 'w')]

# %%
#zip xa organizar, nombres con apellidos.(ejemplo en clase)...etc como transponer una matriz
# tb con variables

# %%
##diccionarios: no seusan mucho

# %%
english_to_spanish = {'dog':'perro', 'daisy':'margarita', 'bottle': 'botella', 'scarf': 'bufanda'}
english_to_spanish
# Out:
# {'dog': 'perro', 'daisy': 'margarita', 'bottle': 'botella', 'scarf': 'bufanda'}

# %%
english_to_spanish['perro']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-206-b81a44dd2ecf> in <module>
# ----> 1 english_to_spanish['perro']
#
# KeyError: 'perro'

# %%
# las claves son unicas, una entrada xa cada valor de la entrada.
#utiles xa buscar cosas xq son ordenados
#las tuplas valen como claves de diccionarion xq son inmutables ((a iferencia de las listas))

# %%
english_to_spanish['dog'] = can
english_to_spanish
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-87a7659b8bbd> in <module>
# ----> 1 english_to_spanish['dog'] = can
#       2 english_to_spanish
#
# NameError: name 'can' is not defined

# %%
popukations ={'Madrid':'spain'
}

# %%
#sets oconjuntos tb con llaves. Sirve xa operaciones de conjjunto.
#esta los 27 en la edad de esta clase
#noguardan duplicados
#

# %%
edades = {35,35,37,27,45,34,34,}
edades
# Out:
# {27, 34, 35, 37, 45}

# %%
edades[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-209-28dc2e45d26a> in <module>
# ----> 1 edades[0]
#
# TypeError: 'set' object does not support indexing

# %%
27 in edades
# Out:
# True

# %%
students = set(my_str_list)
students
# Out:
# {'o'}

# %%
gamberoo

# %%
## list comprehensions

# %%
# forma f¡de hacer un for o un map. resultado una lista

# %%
numbers= [2,5,6]
[n ** 2 for n in numbers]
# Out:
# [4, 25, 36]

# %%
numbers.filter
